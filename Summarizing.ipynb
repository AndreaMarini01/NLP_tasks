# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaMarini01/NLP_tasks/blob/main/Summarizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install spacy
# %pip install nltk
# %pip install transformers
# %pip install transformers
# %pip install torch
# %pip install rouge-score evaluate
# !python -m spacy download it_core_news_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.12.14)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Collecting it-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-3.7.0/it_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 51.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from it-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('it_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy.tokens import Doc
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk import pos_tag, ne_chunk
from nltk.tree import Tree
from typing import List, Tuple
import os
import nltk
import re

# Caricamento del modello spaCy per l'analisi NLP
nlp = spacy.load("it_core_news_sm")

def preprocess_text(text: str) -> str:
    # Suddividi il testo in frasi
    # Imposta una directory locale per il download
    nltk_data_dir = './nltk_data'
    if not os.path.exists(nltk_data_dir):
      os.makedirs(nltk_data_dir)

    nltk.download('punkt_tab', download_dir=nltk_data_dir)
    # Aggiungi manualmente il percorso alla ricerca di NLTK
    nltk.data.path.append(nltk_data_dir)
    sentences = sent_tokenize(text)
    processed_sentences = []

    for sentence in sentences:
        # Rimuovi eventuali spazi iniziali e converti la prima lettera in minuscolo
        if len(sentence) > 1:
            sentence = sentence.strip()  # Rimuovi spazi iniziali/finali
            sentence = sentence[0].lower() + sentence[1:]  # Converte la prima lettera in minuscolo
        processed_sentences.append(sentence)

    # Unisci le frasi con uno spazio, mantenendo i punti
    processed_text = " ".join(processed_sentences)

    # Trasforma in minuscolo ogni parola che segue un punto
    processed_text = re.sub(r'(?<=\.\s)(\w)', lambda match: match.group(0).lower(), processed_text)

    return processed_text

# Funzione per la segmentazione delle frasi
# Segmentazione: trasfromazione del testo in singole frasi
def sentence_segmentation(text: str) -> List[str]:
    return sent_tokenize(text)

# Funzione per la tokenizzazione delle parole
def word_tokenization(sentence: str) -> List[str]:
    return word_tokenize(sentence)

# Funzione per il Part of Speech Tagging
# Assegnamento della funziona grammaticale di una parola
def pos_tagging_with_spacy(text: str) -> List[Tuple[str, str]]:
    doc = nlp(text)  # Analizza il testo con spaCy
    return [(token.text, token.pos_) for token in doc]  # Restituisce i token con i tag POS

# Funzione per la Named Entity Recognition (NER)
# Ricerca di elementi chiave nel testo (entità)
def named_entity_recognition(doc: Doc) -> List[Tuple[str, str]]:
    return [(ent.text, ent.label_) for ent in doc.ents]

# Funzione per la Key Phrase Extraction
# Identificazione di parole chiave rilevanti per l'estrazione
def key_phrase_extraction(doc: Doc) -> List[str]:
    return [chunk.text for chunk in doc.noun_chunks]

# Funzione per il Syntactic Parsing
# Analisi per comprendere le relazioni tra le parole
def syntactic_parsing(doc: Doc):
    return [(token.text, token.dep_, token.head.text) for token in doc]

# Funzione per la Coreference Resolution
# Collegamento tra parole e entità
def coreference_resolution(doc: Doc) -> List[Tuple[str, List[str]]]:
    # Mock: restituirebbe risoluzione dei riferimenti
    return [("entity1", ["pronome1", "entità correlata"])]  # Personalizzare con librerie aggiuntive

# Funzione per la Relation Extraction
# Identificazione delle relazioni tra entità
def relation_extraction(doc: Doc) -> List[Tuple[str, str, str]]:
    relations = []
    for token in doc:
        if token.dep_ == "nsubj" and token.head.dep_ == "ROOT":
            relations.append((token.text, token.head.text, token.head.children))
    return relations

# Funzione per l'Event Extraction
# Individuazione di eventi nel testo
def event_extraction(doc: Doc) -> List[Tuple[str, List[str]]]:
    events = []
    for token in doc:
        if token.ent_type_ in ["EVENT"]:
            events.append((token.text, [child.text for child in token.children]))
    return events

# Pipeline di Information Extraction
def information_extraction_pipeline(text: str):
    sentences = sentence_segmentation(text)
    for sentence in sentences:
        print(f"\nFrase: {sentence}")

        tokens = word_tokenization(sentence)
        print(f"Token: {tokens}")

        pos_tags = pos_tagging_with_spacy(sentence)  # Passa la frase come stringa
        print(f"Part of Speech Tagging: {pos_tags}")

        doc = nlp(sentence)

        ner = named_entity_recognition(doc)
        print(f"Named Entity Recognition: {ner}")

        key_phrases = key_phrase_extraction(doc)
        print(f"Key Phrase Extraction: {key_phrases}")

        syntactic_structure = syntactic_parsing(doc)
        print(f"Syntactic Parsing: {syntactic_structure}")

        coreferences = coreference_resolution(doc)
        print(f"Coreference Resolution: {coreferences}")

        relations = relation_extraction(doc)
        print(f"Relation Extraction: {relations}")

        events = event_extraction(doc)
        print(f"Event Extraction: {events}")


# Lettura del testo da un file
def read_text_from_file(file_path: str) -> str:
    with open(file_path, "r", encoding="utf-8") as file:
        return file.read()

# Esegui la pipeline sul testo di un file
file_path = "/content/TextSummarizing.txt"
testo = read_text_from_file(file_path)
processed_text = preprocess_text(testo)
information_extraction_pipeline(processed_text)
# Out:
# [nltk_data] Downloading package punkt_tab to ./nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Frase: negli ultimi anni, l'Intelligenza Artificiale (IA) ha avuto un impatto profondo e rivoluzionario su molteplici settori, trasformando radicalmente il modo in cui le persone vivono, lavorano e interagiscono con le tecnologie digitali.
# Token: ['negli', 'ultimi', 'anni', ',', "l'Intelligenza", 'Artificiale', '(', 'IA', ')', 'ha', 'avuto', 'un', 'impatto', 'profondo', 'e', 'rivoluzionario', 'su', 'molteplici', 'settori', ',', 'trasformando', 'radicalmente', 'il', 'modo', 'in', 'cui', 'le', 'persone', 'vivono', ',', 'lavorano', 'e', 'interagiscono', 'con', 'le', 'tecnologie', 'digitali', '.']
# Part of Speech Tagging: [('negli', 'ADP'), ('ultimi', 'ADJ'), ('anni', 'NOUN'), (',', 'PUNCT'), ("l'", 'DET'), ('Intelligenza', 'PROPN'), ('Artificiale', 'PROPN'), ('(', 'PUNCT'), ('IA', 'PROPN'), (')', 'PUNCT'), ('ha', 'AUX'), ('avuto', 'VERB'), ('un', 'DET'), ('impatto', 'NOUN'), ('profondo', 'ADJ'), ('e', 'CCONJ'), ('rivoluzionario', 'ADJ'), ('su', 'ADP'), ('molteplici', 'ADJ'), ('settori', 'NOUN'), (',', 'PUNCT'), ('trasformando', 'VERB'), ('radicalmente', 'ADV'), ('il', 'DET'), ('modo', 'NOUN'), ('in', 'ADP'), ('cui', 'PRON'), ('le', 'DET'), ('persone', 'NOUN'), ('vivono', 'VERB'), (',', 'PUNCT'), ('lavorano', 'VERB'), ('e', 'CCONJ'), ('interagiscono', 'VERB'), ('con', 'ADP'), ('le', 'DET'), ('tecnologie', 'NOUN'), ('digitali', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: [('Intelligenza Artificiale', 'ORG'), ('IA', 'MISC')]
# Key Phrase Extraction: ['ultimi anni', "l'Intelligenza Artificiale (IA)", 'un impatto profondo e rivoluzionario su molteplici settori', 'il modo', 'cui', 'le persone', 'le tecnologie digitali']
# Syntactic Parsing: [('negli', 'case', 'anni'), ('ultimi', 'amod', 'anni'), ('anni', 'obl', 'avuto'), (',', 'punct', 'anni'), ("l'", 'det', 'Intelligenza'), ('Intelligenza', 'nsubj', 'avuto'), ('Artificiale', 'flat:name', 'Intelligenza'), ('(', 'punct', 'IA'), ('IA', 'appos', 'Intelligenza'), (')', 'punct', 'IA'), ('ha', 'aux', 'avuto'), ('avuto', 'ROOT', 'avuto'), ('un', 'det', 'impatto'), ('impatto', 'obj', 'avuto'), ('profondo', 'amod', 'impatto'), ('e', 'cc', 'rivoluzionario'), ('rivoluzionario', 'conj', 'profondo'), ('su', 'case', 'settori'), ('molteplici', 'amod', 'settori'), ('settori', 'obl', 'rivoluzionario'), (',', 'punct', 'avuto'), ('trasformando', 'advcl', 'avuto'), ('radicalmente', 'advmod', 'trasformando'), ('il', 'det', 'modo'), ('modo', 'obj', 'trasformando'), ('in', 'case', 'cui'), ('cui', 'obl', 'vivono'), ('le', 'det', 'persone'), ('persone', 'nsubj', 'vivono'), ('vivono', 'acl:relcl', 'modo'), (',', 'punct', 'lavorano'), ('lavorano', 'conj', 'avuto'), ('e', 'cc', 'interagiscono'), ('interagiscono', 'conj', 'avuto'), ('con', 'case', 'tecnologie'), ('le', 'det', 'tecnologie'), ('tecnologie', 'obl', 'interagiscono'), ('digitali', 'amod', 'tecnologie'), ('.', 'punct', 'avuto')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('Intelligenza', 'avuto', <generator object at 0x7e41f8247600>)]
# Event Extraction: []
#
# Frase: tra i vari campi in cui l'IA ha dimostrato il suo potenziale, il Natural Language Processing (NLP) emerge come uno dei più affascinanti e promettenti.
# Token: ['tra', 'i', 'vari', 'campi', 'in', 'cui', "l'IA", 'ha', 'dimostrato', 'il', 'suo', 'potenziale', ',', 'il', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'emerge', 'come', 'uno', 'dei', 'più', 'affascinanti', 'e', 'promettenti', '.']
# Part of Speech Tagging: [('tra', 'ADP'), ('i', 'DET'), ('vari', 'ADJ'), ('campi', 'NOUN'), ('in', 'ADP'), ('cui', 'PRON'), ("l'", 'DET'), ('IA', 'PROPN'), ('ha', 'AUX'), ('dimostrato', 'VERB'), ('il', 'DET'), ('suo', 'DET'), ('potenziale', 'NOUN'), (',', 'PUNCT'), ('il', 'DET'), ('Natural', 'PROPN'), ('Language', 'NOUN'), ('Processing', 'PROPN'), ('(', 'PUNCT'), ('NLP', 'PROPN'), (')', 'PUNCT'), ('emerge', 'VERB'), ('come', 'ADP'), ('uno', 'PRON'), ('dei', 'ADP'), ('più', 'ADV'), ('affascinanti', 'ADJ'), ('e', 'CCONJ'), ('promettenti', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: [('IA', 'MISC'), ('Natural Language Processing', 'MISC'), ('NLP', 'ORG')]
# Key Phrase Extraction: ['i vari campi', 'cui', "l'IA", 'il suo potenziale', 'il Natural Language Processing (NLP)', 'uno']
# Syntactic Parsing: [('tra', 'case', 'campi'), ('i', 'det', 'campi'), ('vari', 'amod', 'campi'), ('campi', 'obl', 'emerge'), ('in', 'case', 'cui'), ('cui', 'obl', 'dimostrato'), ("l'", 'det', 'IA'), ('IA', 'nsubj', 'dimostrato'), ('ha', 'aux', 'dimostrato'), ('dimostrato', 'acl:relcl', 'campi'), ('il', 'det', 'potenziale'), ('suo', 'det:poss', 'potenziale'), ('potenziale', 'obj', 'dimostrato'), (',', 'punct', 'dimostrato'), ('il', 'det', 'Natural'), ('Natural', 'nsubj', 'emerge'), ('Language', 'flat:name', 'Natural'), ('Processing', 'flat:name', 'Natural'), ('(', 'punct', 'NLP'), ('NLP', 'nmod', 'Natural'), (')', 'punct', 'NLP'), ('emerge', 'ROOT', 'emerge'), ('come', 'case', 'uno'), ('uno', 'obl', 'emerge'), ('dei', 'case', 'affascinanti'), ('più', 'advmod', 'affascinanti'), ('affascinanti', 'nmod', 'uno'), ('e', 'cc', 'promettenti'), ('promettenti', 'conj', 'affascinanti'), ('.', 'punct', 'emerge')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('Natural', 'emerge', <generator object at 0x7e41f8247880>)]
# Event Extraction: []
#
# Frase: il suo obiettivo principale è consentire alle macchine di comprendere, analizzare e generare linguaggio naturale, ovvero la forma di comunicazione più naturale e complessa utilizzata dagli esseri umani.
# Token: ['il', 'suo', 'obiettivo', 'principale', 'è', 'consentire', 'alle', 'macchine', 'di', 'comprendere', ',', 'analizzare', 'e', 'generare', 'linguaggio', 'naturale', ',', 'ovvero', 'la', 'forma', 'di', 'comunicazione', 'più', 'naturale', 'e', 'complessa', 'utilizzata', 'dagli', 'esseri', 'umani', '.']
# Part of Speech Tagging: [('il', 'DET'), ('suo', 'DET'), ('obiettivo', 'NOUN'), ('principale', 'ADJ'), ('è', 'AUX'), ('consentire', 'VERB'), ('alle', 'ADP'), ('macchine', 'NOUN'), ('di', 'ADP'), ('comprendere', 'VERB'), (',', 'PUNCT'), ('analizzare', 'VERB'), ('e', 'CCONJ'), ('generare', 'VERB'), ('linguaggio', 'NOUN'), ('naturale', 'ADJ'), (',', 'PUNCT'), ('ovvero', 'CCONJ'), ('la', 'DET'), ('forma', 'NOUN'), ('di', 'ADP'), ('comunicazione', 'NOUN'), ('più', 'ADV'), ('naturale', 'ADJ'), ('e', 'CCONJ'), ('complessa', 'ADJ'), ('utilizzata', 'VERB'), ('dagli', 'ADP'), ('esseri', 'NOUN'), ('umani', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['il suo obiettivo principale', 'macchine', 'linguaggio naturale', ', ovvero la forma', 'comunicazione più naturale e complessa', 'esseri umani']
# Syntactic Parsing: [('il', 'det', 'obiettivo'), ('suo', 'det:poss', 'obiettivo'), ('obiettivo', 'nsubj', 'consentire'), ('principale', 'amod', 'obiettivo'), ('è', 'aux', 'consentire'), ('consentire', 'ROOT', 'consentire'), ('alle', 'case', 'macchine'), ('macchine', 'obl', 'consentire'), ('di', 'mark', 'comprendere'), ('comprendere', 'acl', 'macchine'), (',', 'punct', 'analizzare'), ('analizzare', 'conj', 'comprendere'), ('e', 'cc', 'generare'), ('generare', 'conj', 'comprendere'), ('linguaggio', 'obj', 'generare'), ('naturale', 'amod', 'linguaggio'), (',', 'punct', 'forma'), ('ovvero', 'cc', 'forma'), ('la', 'det', 'forma'), ('forma', 'conj', 'macchine'), ('di', 'case', 'comunicazione'), ('comunicazione', 'nmod', 'forma'), ('più', 'advmod', 'naturale'), ('naturale', 'amod', 'comunicazione'), ('e', 'cc', 'complessa'), ('complessa', 'conj', 'naturale'), ('utilizzata', 'acl', 'comunicazione'), ('dagli', 'case', 'esseri'), ('esseri', 'obl:agent', 'utilizzata'), ('umani', 'amod', 'esseri'), ('.', 'punct', 'consentire')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('obiettivo', 'consentire', <generator object at 0x7e41f82477e0>)]
# Event Extraction: []
#
# Frase: questo campo combina competenze avanzate di linguistica, informatica e matematica, rappresentando una delle aree più multidisciplinari e sfidanti nel panorama tecnologico.
# Token: ['questo', 'campo', 'combina', 'competenze', 'avanzate', 'di', 'linguistica', ',', 'informatica', 'e', 'matematica', ',', 'rappresentando', 'una', 'delle', 'aree', 'più', 'multidisciplinari', 'e', 'sfidanti', 'nel', 'panorama', 'tecnologico', '.']
# Part of Speech Tagging: [('questo', 'DET'), ('campo', 'NOUN'), ('combina', 'VERB'), ('competenze', 'NOUN'), ('avanzate', 'ADJ'), ('di', 'ADP'), ('linguistica', 'NOUN'), (',', 'PUNCT'), ('informatica', 'ADJ'), ('e', 'CCONJ'), ('matematica', 'NOUN'), (',', 'PUNCT'), ('rappresentando', 'VERB'), ('una', 'PRON'), ('delle', 'ADP'), ('aree', 'NOUN'), ('più', 'ADV'), ('multidisciplinari', 'NOUN'), ('e', 'CCONJ'), ('sfidanti', 'NOUN'), ('nel', 'ADP'), ('panorama', 'NOUN'), ('tecnologico', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['questo campo', 'competenze avanzate', 'linguistica', 'matematica', 'una', 'aree più multidisciplinari e sfidanti', 'panorama tecnologico']
# Syntactic Parsing: [('questo', 'det', 'campo'), ('campo', 'nsubj', 'combina'), ('combina', 'ROOT', 'combina'), ('competenze', 'obj', 'combina'), ('avanzate', 'amod', 'competenze'), ('di', 'case', 'linguistica'), ('linguistica', 'nmod', 'competenze'), (',', 'punct', 'informatica'), ('informatica', 'conj', 'linguistica'), ('e', 'cc', 'matematica'), ('matematica', 'conj', 'linguistica'), (',', 'punct', 'competenze'), ('rappresentando', 'advcl', 'combina'), ('una', 'obj', 'rappresentando'), ('delle', 'case', 'aree'), ('aree', 'nmod', 'una'), ('più', 'advmod', 'multidisciplinari'), ('multidisciplinari', 'amod', 'aree'), ('e', 'cc', 'sfidanti'), ('sfidanti', 'conj', 'multidisciplinari'), ('nel', 'case', 'panorama'), ('panorama', 'nmod', 'aree'), ('tecnologico', 'amod', 'panorama'), ('.', 'punct', 'combina')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('campo', 'combina', <generator object at 0x7e41f8247600>)]
# Event Extraction: []
#
# Frase: l’NLP è alla base di molte tecnologie che ormai consideriamo indispensabili nella vita quotidiana.
# Token: ['l', '’', 'NLP', 'è', 'alla', 'base', 'di', 'molte', 'tecnologie', 'che', 'ormai', 'consideriamo', 'indispensabili', 'nella', 'vita', 'quotidiana', '.']
# Part of Speech Tagging: [('l’', 'DET'), ('NLP', 'PROPN'), ('è', 'VERB'), ('alla', 'ADP'), ('base', 'NOUN'), ('di', 'ADP'), ('molte', 'DET'), ('tecnologie', 'NOUN'), ('che', 'PRON'), ('ormai', 'ADV'), ('consideriamo', 'VERB'), ('indispensabili', 'ADJ'), ('nella', 'ADP'), ('vita', 'NOUN'), ('quotidiana', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: [('NLP', 'ORG')]
# Key Phrase Extraction: ['l’NLP', 'base', 'molte tecnologie', 'che', 'vita quotidiana']
# Syntactic Parsing: [('l’', 'det', 'NLP'), ('NLP', 'nsubj', 'è'), ('è', 'ROOT', 'è'), ('alla', 'case', 'base'), ('base', 'obl', 'è'), ('di', 'case', 'tecnologie'), ('molte', 'det', 'tecnologie'), ('tecnologie', 'nmod', 'base'), ('che', 'nsubj', 'consideriamo'), ('ormai', 'advmod', 'consideriamo'), ('consideriamo', 'acl:relcl', 'tecnologie'), ('indispensabili', 'obj', 'consideriamo'), ('nella', 'case', 'vita'), ('vita', 'obl', 'indispensabili'), ('quotidiana', 'amod', 'vita'), ('.', 'punct', 'è')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('NLP', 'è', <generator object at 0x7e41f8247880>)]
# Event Extraction: []
#
# Frase: un esempio è la traduzione automatica, resa popolare da strumenti come Google Translate, che consente a milioni di utenti di superare le barriere linguistiche in tempo reale.
# Token: ['un', 'esempio', 'è', 'la', 'traduzione', 'automatica', ',', 'resa', 'popolare', 'da', 'strumenti', 'come', 'Google', 'Translate', ',', 'che', 'consente', 'a', 'milioni', 'di', 'utenti', 'di', 'superare', 'le', 'barriere', 'linguistiche', 'in', 'tempo', 'reale', '.']
# Part of Speech Tagging: [('un', 'DET'), ('esempio', 'NOUN'), ('è', 'AUX'), ('la', 'DET'), ('traduzione', 'NOUN'), ('automatica', 'ADJ'), (',', 'PUNCT'), ('resa', 'VERB'), ('popolare', 'ADJ'), ('da', 'ADP'), ('strumenti', 'NOUN'), ('come', 'ADP'), ('Google', 'PROPN'), ('Translate', 'PROPN'), (',', 'PUNCT'), ('che', 'PRON'), ('consente', 'VERB'), ('a', 'ADP'), ('milioni', 'NOUN'), ('di', 'ADP'), ('utenti', 'NOUN'), ('di', 'ADP'), ('superare', 'VERB'), ('le', 'DET'), ('barriere', 'NOUN'), ('linguistiche', 'ADJ'), ('in', 'ADP'), ('tempo', 'NOUN'), ('reale', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: [('Google Translate', 'MISC')]
# Key Phrase Extraction: ['un esempio', 'strumenti', 'Google Translate, che consente a milioni di utenti di superare le barriere linguistiche in tempo reale']
# Syntactic Parsing: [('un', 'det', 'esempio'), ('esempio', 'nsubj', 'traduzione'), ('è', 'cop', 'traduzione'), ('la', 'det', 'traduzione'), ('traduzione', 'ROOT', 'traduzione'), ('automatica', 'amod', 'traduzione'), (',', 'punct', 'traduzione'), ('resa', 'acl', 'traduzione'), ('popolare', 'xcomp', 'resa'), ('da', 'case', 'strumenti'), ('strumenti', 'obl:agent', 'resa'), ('come', 'case', 'Google'), ('Google', 'nmod', 'strumenti'), ('Translate', 'flat:name', 'Google'), (',', 'punct', 'Google'), ('che', 'nsubj', 'consente'), ('consente', 'acl:relcl', 'Google'), ('a', 'case', 'milioni'), ('milioni', 'obl', 'consente'), ('di', 'case', 'utenti'), ('utenti', 'nmod', 'milioni'), ('di', 'mark', 'superare'), ('superare', 'advcl', 'consente'), ('le', 'det', 'barriere'), ('barriere', 'obj', 'superare'), ('linguistiche', 'amod', 'barriere'), ('in', 'case', 'tempo'), ('tempo', 'obl', 'superare'), ('reale', 'amod', 'tempo'), ('.', 'punct', 'traduzione')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('esempio', 'traduzione', <generator object at 0x7e41f82479c0>)]
# Event Extraction: []
#
# Frase: questa applicazione si è dimostrata cruciale non solo per il turismo e le interazioni personali, ma anche per il commercio internazionale, dove la velocità e l’accuratezza nella comprensione di documenti multilingue possono fare la differenza tra il successo e il fallimento di un accordo.
# Token: ['questa', 'applicazione', 'si', 'è', 'dimostrata', 'cruciale', 'non', 'solo', 'per', 'il', 'turismo', 'e', 'le', 'interazioni', 'personali', ',', 'ma', 'anche', 'per', 'il', 'commercio', 'internazionale', ',', 'dove', 'la', 'velocità', 'e', 'l', '’', 'accuratezza', 'nella', 'comprensione', 'di', 'documenti', 'multilingue', 'possono', 'fare', 'la', 'differenza', 'tra', 'il', 'successo', 'e', 'il', 'fallimento', 'di', 'un', 'accordo', '.']
# Part of Speech Tagging: [('questa', 'DET'), ('applicazione', 'NOUN'), ('si', 'PRON'), ('è', 'AUX'), ('dimostrata', 'VERB'), ('cruciale', 'ADJ'), ('non', 'ADV'), ('solo', 'ADV'), ('per', 'ADP'), ('il', 'DET'), ('turismo', 'NOUN'), ('e', 'CCONJ'), ('le', 'DET'), ('interazioni', 'NOUN'), ('personali', 'ADJ'), (',', 'PUNCT'), ('ma', 'CCONJ'), ('anche', 'ADV'), ('per', 'ADP'), ('il', 'DET'), ('commercio', 'NOUN'), ('internazionale', 'ADJ'), (',', 'PUNCT'), ('dove', 'ADV'), ('la', 'DET'), ('velocità', 'NOUN'), ('e', 'CCONJ'), ('l’', 'DET'), ('accuratezza', 'NOUN'), ('nella', 'ADP'), ('comprensione', 'NOUN'), ('di', 'ADP'), ('documenti', 'NOUN'), ('multilingue', 'ADJ'), ('possono', 'AUX'), ('fare', 'VERB'), ('la', 'DET'), ('differenza', 'NOUN'), ('tra', 'ADP'), ('il', 'DET'), ('successo', 'NOUN'), ('e', 'CCONJ'), ('il', 'DET'), ('fallimento', 'NOUN'), ('di', 'ADP'), ('un', 'DET'), ('accordo', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['questa applicazione', 'non solo per il turismo', 'le interazioni', ', ma anche per il commercio', 'la velocità', 'l’accuratezza', 'comprensione', 'documenti multilingue', 'la differenza', 'il successo', 'il fallimento', 'un accordo']
# Syntactic Parsing: [('questa', 'det', 'applicazione'), ('applicazione', 'nsubj:pass', 'dimostrata'), ('si', 'expl', 'dimostrata'), ('è', 'aux', 'dimostrata'), ('dimostrata', 'ROOT', 'dimostrata'), ('cruciale', 'xcomp', 'dimostrata'), ('non', 'advmod', 'solo'), ('solo', 'advmod', 'turismo'), ('per', 'case', 'turismo'), ('il', 'det', 'turismo'), ('turismo', 'obl', 'dimostrata'), ('e', 'cc', 'interazioni'), ('le', 'det', 'interazioni'), ('interazioni', 'conj', 'turismo'), ('personali', 'amod', 'interazioni'), (',', 'punct', 'commercio'), ('ma', 'cc', 'commercio'), ('anche', 'advmod', 'commercio'), ('per', 'case', 'commercio'), ('il', 'det', 'commercio'), ('commercio', 'conj', 'turismo'), ('internazionale', 'amod', 'commercio'), (',', 'punct', 'commercio'), ('dove', 'advmod', 'fare'), ('la', 'det', 'velocità'), ('velocità', 'nsubj', 'fare'), ('e', 'cc', 'accuratezza'), ('l’', 'det', 'accuratezza'), ('accuratezza', 'conj', 'velocità'), ('nella', 'case', 'comprensione'), ('comprensione', 'nmod', 'velocità'), ('di', 'case', 'documenti'), ('documenti', 'nmod', 'comprensione'), ('multilingue', 'amod', 'documenti'), ('possono', 'aux', 'fare'), ('fare', 'acl:relcl', 'commercio'), ('la', 'det', 'differenza'), ('differenza', 'obj', 'fare'), ('tra', 'case', 'successo'), ('il', 'det', 'successo'), ('successo', 'nmod', 'differenza'), ('e', 'cc', 'fallimento'), ('il', 'det', 'fallimento'), ('fallimento', 'conj', 'successo'), ('di', 'case', 'accordo'), ('un', 'det', 'accordo'), ('accordo', 'nmod', 'fallimento'), ('.', 'punct', 'dimostrata')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: []
# Event Extraction: []
#
# Frase: un’altra applicazione centrale è l’analisi del sentiment, utilizzata in particolare nel marketing e nelle ricerche di mercato.
# Token: ['un', '’', 'altra', 'applicazione', 'centrale', 'è', 'l', '’', 'analisi', 'del', 'sentiment', ',', 'utilizzata', 'in', 'particolare', 'nel', 'marketing', 'e', 'nelle', 'ricerche', 'di', 'mercato', '.']
# Part of Speech Tagging: [('un’', 'DET'), ('altra', 'ADJ'), ('applicazione', 'NOUN'), ('centrale', 'ADJ'), ('è', 'AUX'), ('l’', 'DET'), ('analisi', 'NOUN'), ('del', 'ADP'), ('sentiment', 'NOUN'), (',', 'PUNCT'), ('utilizzata', 'VERB'), ('in', 'ADP'), ('particolare', 'NOUN'), ('nel', 'ADP'), ('marketing', 'NOUN'), ('e', 'CCONJ'), ('nelle', 'ADP'), ('ricerche', 'NOUN'), ('di', 'ADP'), ('mercato', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['un’altra applicazione centrale', 'sentiment', 'particolare', 'marketing', 'nelle ricerche', 'mercato']
# Syntactic Parsing: [('un’', 'det', 'applicazione'), ('altra', 'amod', 'applicazione'), ('applicazione', 'nsubj', 'analisi'), ('centrale', 'amod', 'applicazione'), ('è', 'cop', 'analisi'), ('l’', 'det', 'analisi'), ('analisi', 'ROOT', 'analisi'), ('del', 'case', 'sentiment'), ('sentiment', 'nmod', 'analisi'), (',', 'punct', 'analisi'), ('utilizzata', 'acl', 'analisi'), ('in', 'case', 'particolare'), ('particolare', 'obl', 'utilizzata'), ('nel', 'case', 'marketing'), ('marketing', 'obl', 'utilizzata'), ('e', 'cc', 'ricerche'), ('nelle', 'case', 'ricerche'), ('ricerche', 'conj', 'marketing'), ('di', 'case', 'mercato'), ('mercato', 'nmod', 'ricerche'), ('.', 'punct', 'analisi')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('applicazione', 'analisi', <generator object at 0x7e41f8247920>)]
# Event Extraction: []
#
# Frase: attraverso l’analisi automatizzata di testi provenienti da social media, recensioni e sondaggi, le aziende possono ottenere una panoramica delle opinioni e dei sentimenti del pubblico nei confronti di un prodotto, un servizio o un marchio.
# Token: ['attraverso', 'l', '’', 'analisi', 'automatizzata', 'di', 'testi', 'provenienti', 'da', 'social', 'media', ',', 'recensioni', 'e', 'sondaggi', ',', 'le', 'aziende', 'possono', 'ottenere', 'una', 'panoramica', 'delle', 'opinioni', 'e', 'dei', 'sentimenti', 'del', 'pubblico', 'nei', 'confronti', 'di', 'un', 'prodotto', ',', 'un', 'servizio', 'o', 'un', 'marchio', '.']
# Part of Speech Tagging: [('attraverso', 'ADP'), ('l’', 'DET'), ('analisi', 'NOUN'), ('automatizzata', 'VERB'), ('di', 'ADP'), ('testi', 'NOUN'), ('provenienti', 'VERB'), ('da', 'ADP'), ('social', 'NOUN'), ('media', 'ADJ'), (',', 'PUNCT'), ('recensioni', 'NOUN'), ('e', 'CCONJ'), ('sondaggi', 'NOUN'), (',', 'PUNCT'), ('le', 'DET'), ('aziende', 'NOUN'), ('possono', 'AUX'), ('ottenere', 'VERB'), ('una', 'DET'), ('panoramica', 'NOUN'), ('delle', 'ADP'), ('opinioni', 'NOUN'), ('e', 'CCONJ'), ('dei', 'ADP'), ('sentimenti', 'NOUN'), ('del', 'ADP'), ('pubblico', 'NOUN'), ('nei', 'ADP'), ('confronti', 'NOUN'), ('di', 'ADP'), ('un', 'DET'), ('prodotto', 'NOUN'), (',', 'PUNCT'), ('un', 'DET'), ('servizio', 'NOUN'), ('o', 'CCONJ'), ('un', 'DET'), ('marchio', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['l’analisi', 'testi', 'social media', ', recensioni', 'sondaggi', 'le aziende', 'una panoramica', 'opinioni', 'dei sentimenti', 'pubblico', 'confronti', 'un prodotto', ', un servizio', 'un marchio']
# Syntactic Parsing: [('attraverso', 'case', 'analisi'), ('l’', 'det', 'analisi'), ('analisi', 'obl', 'ottenere'), ('automatizzata', 'acl', 'analisi'), ('di', 'case', 'testi'), ('testi', 'obl', 'automatizzata'), ('provenienti', 'acl', 'testi'), ('da', 'case', 'social'), ('social', 'obl', 'provenienti'), ('media', 'amod', 'social'), (',', 'punct', 'recensioni'), ('recensioni', 'conj', 'social'), ('e', 'cc', 'sondaggi'), ('sondaggi', 'conj', 'social'), (',', 'punct', 'analisi'), ('le', 'det', 'aziende'), ('aziende', 'nsubj', 'ottenere'), ('possono', 'aux', 'ottenere'), ('ottenere', 'ROOT', 'ottenere'), ('una', 'det', 'panoramica'), ('panoramica', 'obj', 'ottenere'), ('delle', 'case', 'opinioni'), ('opinioni', 'nmod', 'panoramica'), ('e', 'cc', 'sentimenti'), ('dei', 'case', 'sentimenti'), ('sentimenti', 'conj', 'opinioni'), ('del', 'case', 'pubblico'), ('pubblico', 'nmod', 'sentimenti'), ('nei', 'case', 'confronti'), ('confronti', 'nmod', 'sentimenti'), ('di', 'case', 'prodotto'), ('un', 'det', 'prodotto'), ('prodotto', 'nmod', 'confronti'), (',', 'punct', 'servizio'), ('un', 'det', 'servizio'), ('servizio', 'conj', 'panoramica'), ('o', 'cc', 'marchio'), ('un', 'det', 'marchio'), ('marchio', 'conj', 'panoramica'), ('.', 'punct', 'ottenere')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('aziende', 'ottenere', <generator object at 0x7e41f8247740>)]
# Event Extraction: []
#
# Frase: questo tipo di analisi consente di individuare tendenze emergenti, anticipare crisi reputazionali e personalizzare le strategie di comunicazione.
# Token: ['questo', 'tipo', 'di', 'analisi', 'consente', 'di', 'individuare', 'tendenze', 'emergenti', ',', 'anticipare', 'crisi', 'reputazionali', 'e', 'personalizzare', 'le', 'strategie', 'di', 'comunicazione', '.']
# Part of Speech Tagging: [('questo', 'DET'), ('tipo', 'NOUN'), ('di', 'ADP'), ('analisi', 'NOUN'), ('consente', 'VERB'), ('di', 'ADP'), ('individuare', 'VERB'), ('tendenze', 'NOUN'), ('emergenti', 'ADJ'), (',', 'PUNCT'), ('anticipare', 'VERB'), ('crisi', 'NOUN'), ('reputazionali', 'ADJ'), ('e', 'CCONJ'), ('personalizzare', 'VERB'), ('le', 'DET'), ('strategie', 'NOUN'), ('di', 'ADP'), ('comunicazione', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['questo tipo', 'analisi', 'tendenze emergenti', 'crisi reputazionali', 'le strategie', 'comunicazione']
# Syntactic Parsing: [('questo', 'det', 'tipo'), ('tipo', 'nsubj', 'consente'), ('di', 'case', 'analisi'), ('analisi', 'nmod', 'tipo'), ('consente', 'ROOT', 'consente'), ('di', 'mark', 'individuare'), ('individuare', 'xcomp', 'consente'), ('tendenze', 'obj', 'individuare'), ('emergenti', 'amod', 'tendenze'), (',', 'punct', 'anticipare'), ('anticipare', 'conj', 'individuare'), ('crisi', 'obj', 'anticipare'), ('reputazionali', 'amod', 'crisi'), ('e', 'cc', 'personalizzare'), ('personalizzare', 'conj', 'individuare'), ('le', 'det', 'strategie'), ('strategie', 'obj', 'personalizzare'), ('di', 'case', 'comunicazione'), ('comunicazione', 'nmod', 'strategie'), ('.', 'punct', 'consente')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('tipo', 'consente', <generator object at 0x7e41f82479c0>)]
# Event Extraction: []
#
# Frase: allo stesso modo, i chatbot e gli assistenti virtuali, come Siri, Alexa e Google Assistant, hanno reso possibile un’interazione più naturale tra le persone e i dispositivi tecnologici, semplificando compiti quotidiani come la gestione di calendari, l'acquisto online e la ricerca di informazioni.
# Token: ['allo', 'stesso', 'modo', ',', 'i', 'chatbot', 'e', 'gli', 'assistenti', 'virtuali', ',', 'come', 'Siri', ',', 'Alexa', 'e', 'Google', 'Assistant', ',', 'hanno', 'reso', 'possibile', 'un', '’', 'interazione', 'più', 'naturale', 'tra', 'le', 'persone', 'e', 'i', 'dispositivi', 'tecnologici', ',', 'semplificando', 'compiti', 'quotidiani', 'come', 'la', 'gestione', 'di', 'calendari', ',', "l'acquisto", 'online', 'e', 'la', 'ricerca', 'di', 'informazioni', '.']
# Part of Speech Tagging: [('allo', 'ADP'), ('stesso', 'ADJ'), ('modo', 'NOUN'), (',', 'PUNCT'), ('i', 'DET'), ('chatbot', 'NOUN'), ('e', 'CCONJ'), ('gli', 'DET'), ('assistenti', 'NOUN'), ('virtuali', 'ADJ'), (',', 'PUNCT'), ('come', 'ADP'), ('Siri', 'PROPN'), (',', 'PUNCT'), ('Alexa', 'PROPN'), ('e', 'CCONJ'), ('Google', 'PROPN'), ('Assistant', 'PROPN'), (',', 'PUNCT'), ('hanno', 'AUX'), ('reso', 'VERB'), ('possibile', 'ADJ'), ('un’', 'DET'), ('interazione', 'NOUN'), ('più', 'ADV'), ('naturale', 'ADJ'), ('tra', 'ADP'), ('le', 'DET'), ('persone', 'NOUN'), ('e', 'CCONJ'), ('i', 'DET'), ('dispositivi', 'NOUN'), ('tecnologici', 'ADJ'), (',', 'PUNCT'), ('semplificando', 'VERB'), ('compiti', 'NOUN'), ('quotidiani', 'NOUN'), ('come', 'ADP'), ('la', 'DET'), ('gestione', 'NOUN'), ('di', 'ADP'), ('calendari', 'NOUN'), (',', 'PUNCT'), ("l'", 'DET'), ('acquisto', 'NOUN'), ('online', 'ADJ'), ('e', 'CCONJ'), ('la', 'DET'), ('ricerca', 'NOUN'), ('di', 'ADP'), ('informazioni', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: [('Siri', 'LOC'), ('Alexa', 'LOC'), ('Google Assistant', 'PER')]
# Key Phrase Extraction: ['stesso modo', ', i chatbot', 'gli assistenti', 'Siri', ', Alexa', 'Google', 'un’interazione più naturale', 'le persone', 'i dispositivi', 'compiti quotidiani come la gestione di calendari', "l'acquisto online", 'la ricerca', 'informazioni']
# Syntactic Parsing: [('allo', 'case', 'modo'), ('stesso', 'amod', 'modo'), ('modo', 'obl', 'reso'), (',', 'punct', 'chatbot'), ('i', 'det', 'chatbot'), ('chatbot', 'conj', 'modo'), ('e', 'cc', 'assistenti'), ('gli', 'det', 'assistenti'), ('assistenti', 'conj', 'modo'), ('virtuali', 'amod', 'assistenti'), (',', 'punct', 'assistenti'), ('come', 'case', 'Siri'), ('Siri', 'nmod', 'assistenti'), (',', 'punct', 'Alexa'), ('Alexa', 'conj', 'Siri'), ('e', 'cc', 'Google'), ('Google', 'conj', 'Siri'), ('Assistant', 'flat:name', 'Google'), (',', 'punct', 'modo'), ('hanno', 'aux', 'reso'), ('reso', 'ROOT', 'reso'), ('possibile', 'xcomp', 'reso'), ('un’', 'det', 'interazione'), ('interazione', 'obj', 'reso'), ('più', 'advmod', 'naturale'), ('naturale', 'amod', 'interazione'), ('tra', 'case', 'persone'), ('le', 'det', 'persone'), ('persone', 'nmod', 'interazione'), ('e', 'cc', 'dispositivi'), ('i', 'det', 'dispositivi'), ('dispositivi', 'conj', 'persone'), ('tecnologici', 'amod', 'dispositivi'), (',', 'punct', 'reso'), ('semplificando', 'advcl', 'reso'), ('compiti', 'obj', 'semplificando'), ('quotidiani', 'compound', 'compiti'), ('come', 'case', 'gestione'), ('la', 'det', 'gestione'), ('gestione', 'nmod', 'compiti'), ('di', 'case', 'calendari'), ('calendari', 'nmod', 'gestione'), (',', 'punct', 'reso'), ("l'", 'det', 'acquisto'), ('acquisto', 'obj', 'reso'), ('online', 'amod', 'acquisto'), ('e', 'cc', 'ricerca'), ('la', 'det', 'ricerca'), ('ricerca', 'conj', 'acquisto'), ('di', 'case', 'informazioni'), ('informazioni', 'nmod', 'ricerca'), ('.', 'punct', 'reso')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: []
# Event Extraction: []
#
# Frase: un’ulteriore applicazione dell’NLP, che ha guadagnato grande popolarità, è il summarizing automatico.
# Token: ['un', '’', 'ulteriore', 'applicazione', 'dell', '’', 'NLP', ',', 'che', 'ha', 'guadagnato', 'grande', 'popolarità', ',', 'è', 'il', 'summarizing', 'automatico', '.']
# Part of Speech Tagging: [('un’', 'DET'), ('ulteriore', 'ADJ'), ('applicazione', 'NOUN'), ('dell’', 'ADP'), ('NLP', 'PROPN'), (',', 'PUNCT'), ('che', 'PRON'), ('ha', 'AUX'), ('guadagnato', 'VERB'), ('grande', 'ADJ'), ('popolarità', 'NOUN'), (',', 'PUNCT'), ('è', 'AUX'), ('il', 'DET'), ('summarizing', 'NOUN'), ('automatico', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: [('NLP', 'ORG')]
# Key Phrase Extraction: ['un’ulteriore applicazione', 'NLP', 'che', 'grande popolarità']
# Syntactic Parsing: [('un’', 'det', 'applicazione'), ('ulteriore', 'amod', 'applicazione'), ('applicazione', 'nsubj', 'summarizing'), ('dell’', 'case', 'NLP'), ('NLP', 'nmod', 'applicazione'), (',', 'punct', 'NLP'), ('che', 'nsubj', 'guadagnato'), ('ha', 'aux', 'guadagnato'), ('guadagnato', 'acl:relcl', 'NLP'), ('grande', 'amod', 'popolarità'), ('popolarità', 'obj', 'guadagnato'), (',', 'punct', 'applicazione'), ('è', 'cop', 'summarizing'), ('il', 'det', 'summarizing'), ('summarizing', 'ROOT', 'summarizing'), ('automatico', 'amod', 'summarizing'), ('.', 'punct', 'summarizing')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('applicazione', 'summarizing', <generator object at 0x7e41f8247740>)]
# Event Extraction: []
#
# Frase: questo strumento permette di sintetizzare grandi quantità di informazioni in riassunti concisi e facilmente comprensibili.
# Token: ['questo', 'strumento', 'permette', 'di', 'sintetizzare', 'grandi', 'quantità', 'di', 'informazioni', 'in', 'riassunti', 'concisi', 'e', 'facilmente', 'comprensibili', '.']
# Part of Speech Tagging: [('questo', 'DET'), ('strumento', 'NOUN'), ('permette', 'VERB'), ('di', 'ADP'), ('sintetizzare', 'VERB'), ('grandi', 'ADJ'), ('quantità', 'NOUN'), ('di', 'ADP'), ('informazioni', 'NOUN'), ('in', 'ADP'), ('riassunti', 'NOUN'), ('concisi', 'ADJ'), ('e', 'CCONJ'), ('facilmente', 'ADV'), ('comprensibili', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['questo strumento', 'grandi quantità', 'informazioni', 'riassunti concisi e facilmente comprensibili']
# Syntactic Parsing: [('questo', 'det', 'strumento'), ('strumento', 'nsubj', 'permette'), ('permette', 'ROOT', 'permette'), ('di', 'mark', 'sintetizzare'), ('sintetizzare', 'ccomp', 'permette'), ('grandi', 'amod', 'quantità'), ('quantità', 'obj', 'sintetizzare'), ('di', 'case', 'informazioni'), ('informazioni', 'nmod', 'quantità'), ('in', 'case', 'riassunti'), ('riassunti', 'nmod', 'informazioni'), ('concisi', 'amod', 'riassunti'), ('e', 'cc', 'comprensibili'), ('facilmente', 'advmod', 'comprensibili'), ('comprensibili', 'conj', 'concisi'), ('.', 'punct', 'permette')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('strumento', 'permette', <generator object at 0x7e41f8247920>)]
# Event Extraction: []
#
# Frase: la sintesi dei testi è particolarmente utile in settori come il giornalismo, dove è necessario processare rapidamente notizie da fonti disparate, e nella ricerca scientifica, dove i ricercatori devono districarsi tra una mole sempre crescente di articoli accademici.
# Token: ['la', 'sintesi', 'dei', 'testi', 'è', 'particolarmente', 'utile', 'in', 'settori', 'come', 'il', 'giornalismo', ',', 'dove', 'è', 'necessario', 'processare', 'rapidamente', 'notizie', 'da', 'fonti', 'disparate', ',', 'e', 'nella', 'ricerca', 'scientifica', ',', 'dove', 'i', 'ricercatori', 'devono', 'districarsi', 'tra', 'una', 'mole', 'sempre', 'crescente', 'di', 'articoli', 'accademici', '.']
# Part of Speech Tagging: [('la', 'DET'), ('sintesi', 'NOUN'), ('dei', 'ADP'), ('testi', 'NOUN'), ('è', 'AUX'), ('particolarmente', 'ADV'), ('utile', 'ADJ'), ('in', 'ADP'), ('settori', 'NOUN'), ('come', 'ADP'), ('il', 'DET'), ('giornalismo', 'NOUN'), (',', 'PUNCT'), ('dove', 'ADV'), ('è', 'AUX'), ('necessario', 'ADJ'), ('processare', 'VERB'), ('rapidamente', 'ADV'), ('notizie', 'NOUN'), ('da', 'ADP'), ('fonti', 'NOUN'), ('disparate', 'ADJ'), (',', 'PUNCT'), ('e', 'CCONJ'), ('nella', 'ADP'), ('ricerca', 'NOUN'), ('scientifica', 'ADJ'), (',', 'PUNCT'), ('dove', 'ADV'), ('i', 'DET'), ('ricercatori', 'NOUN'), ('devono', 'AUX'), ('districarsi', 'VERB'), ('tra', 'ADP'), ('una', 'DET'), ('mole', 'NOUN'), ('sempre', 'ADV'), ('crescente', 'ADJ'), ('di', 'ADP'), ('articoli', 'NOUN'), ('accademici', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['la sintesi', 'testi', 'settori', 'il giornalismo', 'notizie', 'fonti disparate', ', e nella ricerca', 'i ricercatori', 'una mole sempre crescente di articoli accademici']
# Syntactic Parsing: [('la', 'det', 'sintesi'), ('sintesi', 'nsubj', 'utile'), ('dei', 'case', 'testi'), ('testi', 'nmod', 'sintesi'), ('è', 'cop', 'utile'), ('particolarmente', 'advmod', 'utile'), ('utile', 'ROOT', 'utile'), ('in', 'case', 'settori'), ('settori', 'obl', 'utile'), ('come', 'case', 'giornalismo'), ('il', 'det', 'giornalismo'), ('giornalismo', 'nmod', 'settori'), (',', 'punct', 'giornalismo'), ('dove', 'advmod', 'necessario'), ('è', 'cop', 'necessario'), ('necessario', 'acl:relcl', 'giornalismo'), ('processare', 'csubj', 'necessario'), ('rapidamente', 'advmod', 'processare'), ('notizie', 'obj', 'processare'), ('da', 'case', 'fonti'), ('fonti', 'nmod', 'notizie'), ('disparate', 'amod', 'fonti'), (',', 'punct', 'ricerca'), ('e', 'cc', 'ricerca'), ('nella', 'case', 'ricerca'), ('ricerca', 'conj', 'fonti'), ('scientifica', 'amod', 'ricerca'), (',', 'punct', 'ricerca'), ('dove', 'advmod', 'districarsi'), ('i', 'det', 'ricercatori'), ('ricercatori', 'nsubj', 'districarsi'), ('devono', 'aux', 'districarsi'), ('districarsi', 'acl:relcl', 'ricerca'), ('tra', 'case', 'mole'), ('una', 'det', 'mole'), ('mole', 'obl', 'districarsi'), ('sempre', 'advmod', 'crescente'), ('crescente', 'amod', 'mole'), ('di', 'case', 'articoli'), ('articoli', 'obl', 'crescente'), ('accademici', 'amod', 'articoli'), ('.', 'punct', 'utile')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('sintesi', 'utile', <generator object at 0x7e41f82479c0>)]
# Event Extraction: []
#
# Frase: sebbene i progressi siano stati significativi, rimangono sfide legate alla capacità dei modelli di mantenere la coerenza, la precisione e l’importanza delle informazioni nel testo sintetizzato.
# Token: ['sebbene', 'i', 'progressi', 'siano', 'stati', 'significativi', ',', 'rimangono', 'sfide', 'legate', 'alla', 'capacità', 'dei', 'modelli', 'di', 'mantenere', 'la', 'coerenza', ',', 'la', 'precisione', 'e', 'l', '’', 'importanza', 'delle', 'informazioni', 'nel', 'testo', 'sintetizzato', '.']
# Part of Speech Tagging: [('sebbene', 'SCONJ'), ('i', 'DET'), ('progressi', 'NOUN'), ('siano', 'AUX'), ('stati', 'AUX'), ('significativi', 'ADJ'), (',', 'PUNCT'), ('rimangono', 'VERB'), ('sfide', 'NOUN'), ('legate', 'VERB'), ('alla', 'ADP'), ('capacità', 'NOUN'), ('dei', 'ADP'), ('modelli', 'NOUN'), ('di', 'ADP'), ('mantenere', 'VERB'), ('la', 'DET'), ('coerenza', 'NOUN'), (',', 'PUNCT'), ('la', 'DET'), ('precisione', 'NOUN'), ('e', 'CCONJ'), ('l’', 'DET'), ('importanza', 'NOUN'), ('delle', 'ADP'), ('informazioni', 'NOUN'), ('nel', 'ADP'), ('testo', 'NOUN'), ('sintetizzato', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['i progressi', 'sfide', 'capacità', 'modelli', 'la coerenza', ', la precisione', 'l’importanza', 'informazioni', 'testo sintetizzato']
# Syntactic Parsing: [('sebbene', 'mark', 'significativi'), ('i', 'det', 'progressi'), ('progressi', 'nsubj', 'significativi'), ('siano', 'aux', 'significativi'), ('stati', 'cop', 'significativi'), ('significativi', 'advcl', 'rimangono'), (',', 'punct', 'significativi'), ('rimangono', 'ROOT', 'rimangono'), ('sfide', 'obj', 'rimangono'), ('legate', 'acl', 'sfide'), ('alla', 'case', 'capacità'), ('capacità', 'obl', 'legate'), ('dei', 'case', 'modelli'), ('modelli', 'nmod', 'capacità'), ('di', 'mark', 'mantenere'), ('mantenere', 'acl', 'capacità'), ('la', 'det', 'coerenza'), ('coerenza', 'obj', 'mantenere'), (',', 'punct', 'precisione'), ('la', 'det', 'precisione'), ('precisione', 'conj', 'coerenza'), ('e', 'cc', 'importanza'), ('l’', 'det', 'importanza'), ('importanza', 'conj', 'coerenza'), ('delle', 'case', 'informazioni'), ('informazioni', 'nmod', 'importanza'), ('nel', 'case', 'testo'), ('testo', 'nmod', 'informazioni'), ('sintetizzato', 'amod', 'testo'), ('.', 'punct', 'rimangono')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: []
# Event Extraction: []
#
# Frase: gli sviluppi tecnologici nel campo dell'NLP sono stati trainati dall’introduzione di modelli di linguaggio di grandi dimensioni, come BERT (Bidirectional Encoder Representations from Transformers), GPT (Generative Pre-trained Transformer) e RoBERTa.
# Token: ['gli', 'sviluppi', 'tecnologici', 'nel', 'campo', "dell'NLP", 'sono', 'stati', 'trainati', 'dall', '’', 'introduzione', 'di', 'modelli', 'di', 'linguaggio', 'di', 'grandi', 'dimensioni', ',', 'come', 'BERT', '(', 'Bidirectional', 'Encoder', 'Representations', 'from', 'Transformers', ')', ',', 'GPT', '(', 'Generative', 'Pre-trained', 'Transformer', ')', 'e', 'RoBERTa', '.']
# Part of Speech Tagging: [('gli', 'DET'), ('sviluppi', 'NOUN'), ('tecnologici', 'ADJ'), ('nel', 'ADP'), ('campo', 'NOUN'), ("dell'", 'ADP'), ('NLP', 'PROPN'), ('sono', 'AUX'), ('stati', 'AUX'), ('trainati', 'VERB'), ('dall’', 'ADP'), ('introduzione', 'NOUN'), ('di', 'ADP'), ('modelli', 'NOUN'), ('di', 'ADP'), ('linguaggio', 'NOUN'), ('di', 'ADP'), ('grandi', 'ADJ'), ('dimensioni', 'NOUN'), (',', 'PUNCT'), ('come', 'ADP'), ('BERT', 'PROPN'), ('(', 'PUNCT'), ('Bidirectional', 'PROPN'), ('Encoder', 'PROPN'), ('Representations', 'PROPN'), ('from', 'X'), ('Transformers', 'PROPN'), (')', 'PUNCT'), (',', 'PUNCT'), ('GPT', 'PROPN'), ('(', 'PUNCT'), ('Generative', 'PROPN'), ('Pre', 'PROPN'), ('-', 'PUNCT'), ('trained', 'PROPN'), ('Transformer', 'PROPN'), (')', 'PUNCT'), ('e', 'CCONJ'), ('RoBERTa', 'PROPN'), ('.', 'PUNCT')]
# Named Entity Recognition: [('NLP', 'ORG'), ('BERT', 'MISC'), ('Bidirectional Encoder Representations from Transformers', 'MISC'), ('GPT', 'MISC'), ('Generative Pre-trained Transformer', 'MISC')]
# Key Phrase Extraction: ['gli sviluppi tecnologici', 'campo', 'NLP', 'introduzione', 'modelli', 'linguaggio', 'grandi dimensioni', 'BERT', '(Bidirectional', 'Encoder', 'Transformers', ', GPT', '(Generative Pre-trained Transformer)', 'RoBERTa']
# Syntactic Parsing: [('gli', 'det', 'sviluppi'), ('sviluppi', 'nsubj:pass', 'trainati'), ('tecnologici', 'amod', 'sviluppi'), ('nel', 'case', 'campo'), ('campo', 'nmod', 'sviluppi'), ("dell'", 'case', 'NLP'), ('NLP', 'nmod', 'campo'), ('sono', 'aux', 'trainati'), ('stati', 'aux:pass', 'trainati'), ('trainati', 'ROOT', 'trainati'), ('dall’', 'case', 'introduzione'), ('introduzione', 'obl', 'trainati'), ('di', 'case', 'modelli'), ('modelli', 'nmod', 'introduzione'), ('di', 'case', 'linguaggio'), ('linguaggio', 'nmod', 'modelli'), ('di', 'case', 'dimensioni'), ('grandi', 'amod', 'dimensioni'), ('dimensioni', 'nmod', 'linguaggio'), (',', 'punct', 'trainati'), ('come', 'case', 'BERT'), ('BERT', 'obl', 'trainati'), ('(', 'punct', 'Bidirectional'), ('Bidirectional', 'appos', 'BERT'), ('Encoder', 'nmod', 'Bidirectional'), ('Representations', 'flat:name', 'Bidirectional'), ('from', 'nmod', 'Bidirectional'), ('Transformers', 'nmod', 'Bidirectional'), (')', 'punct', 'Bidirectional'), (',', 'punct', 'GPT'), ('GPT', 'conj', 'BERT'), ('(', 'punct', 'Generative'), ('Generative', 'nmod', 'GPT'), ('Pre', 'flat:name', 'Generative'), ('-', 'punct', 'Generative'), ('trained', 'compound', 'Generative'), ('Transformer', 'nmod', 'Generative'), (')', 'punct', 'Generative'), ('e', 'cc', 'RoBERTa'), ('RoBERTa', 'conj', 'BERT'), ('.', 'punct', 'trainati')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: []
# Event Extraction: []
#
# Frase: questi modelli, basati sull’architettura Transformer, hanno rivoluzionato l’approccio tradizionale al linguaggio naturale, dimostrando una capacità senza precedenti di comprendere il contesto e catturare relazioni semantiche complesse all’interno dei testi.
# Token: ['questi', 'modelli', ',', 'basati', 'sull', '’', 'architettura', 'Transformer', ',', 'hanno', 'rivoluzionato', 'l', '’', 'approccio', 'tradizionale', 'al', 'linguaggio', 'naturale', ',', 'dimostrando', 'una', 'capacità', 'senza', 'precedenti', 'di', 'comprendere', 'il', 'contesto', 'e', 'catturare', 'relazioni', 'semantiche', 'complesse', 'all', '’', 'interno', 'dei', 'testi', '.']
# Part of Speech Tagging: [('questi', 'DET'), ('modelli', 'NOUN'), (',', 'PUNCT'), ('basati', 'NOUN'), ('sull’', 'ADP'), ('architettura', 'NOUN'), ('Transformer', 'PROPN'), (',', 'PUNCT'), ('hanno', 'AUX'), ('rivoluzionato', 'VERB'), ('l’', 'DET'), ('approccio', 'NOUN'), ('tradizionale', 'ADJ'), ('al', 'ADP'), ('linguaggio', 'NOUN'), ('naturale', 'ADJ'), (',', 'PUNCT'), ('dimostrando', 'VERB'), ('una', 'DET'), ('capacità', 'NOUN'), ('senza', 'ADP'), ('precedenti', 'NOUN'), ('di', 'ADP'), ('comprendere', 'VERB'), ('il', 'DET'), ('contesto', 'NOUN'), ('e', 'CCONJ'), ('catturare', 'VERB'), ('relazioni', 'NOUN'), ('semantiche', 'ADJ'), ('complesse', 'ADJ'), ('all’', 'ADP'), ('interno', 'NOUN'), ('dei', 'ADP'), ('testi', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: [('sull’', 'MISC'), ('Transformer', 'MISC')]
# Key Phrase Extraction: ['questi modelli', 'architettura', 'Transformer', 'l’approccio tradizionale', 'linguaggio naturale', 'una capacità', 'precedenti', 'il contesto', 'relazioni semantiche', 'interno', 'testi']
# Syntactic Parsing: [('questi', 'det', 'modelli'), ('modelli', 'nsubj', 'rivoluzionato'), (',', 'punct', 'modelli'), ('basati', 'acl', 'modelli'), ('sull’', 'case', 'architettura'), ('architettura', 'obl:agent', 'basati'), ('Transformer', 'nmod', 'architettura'), (',', 'punct', 'modelli'), ('hanno', 'aux', 'rivoluzionato'), ('rivoluzionato', 'ROOT', 'rivoluzionato'), ('l’', 'det', 'approccio'), ('approccio', 'obj', 'rivoluzionato'), ('tradizionale', 'amod', 'approccio'), ('al', 'case', 'linguaggio'), ('linguaggio', 'nmod', 'approccio'), ('naturale', 'amod', 'linguaggio'), (',', 'punct', 'rivoluzionato'), ('dimostrando', 'advcl', 'rivoluzionato'), ('una', 'det', 'capacità'), ('capacità', 'obj', 'dimostrando'), ('senza', 'case', 'precedenti'), ('precedenti', 'nmod', 'capacità'), ('di', 'mark', 'comprendere'), ('comprendere', 'xcomp', 'dimostrando'), ('il', 'det', 'contesto'), ('contesto', 'obj', 'comprendere'), ('e', 'cc', 'catturare'), ('catturare', 'conj', 'comprendere'), ('relazioni', 'obj', 'catturare'), ('semantiche', 'amod', 'relazioni'), ('complesse', 'amod', 'relazioni'), ('all’', 'case', 'interno'), ('interno', 'obl', 'complesse'), ('dei', 'case', 'testi'), ('testi', 'nmod', 'interno'), ('.', 'punct', 'rivoluzionato')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('modelli', 'rivoluzionato', <generator object at 0x7e41f8247740>)]
# Event Extraction: []
#
# Frase: la loro forza risiede nell’uso di tecniche di pre-addestramento su dataset di dimensioni enormi, che includono miliardi di parole provenienti da libri, articoli e pagine web.
# Token: ['la', 'loro', 'forza', 'risiede', 'nell', '’', 'uso', 'di', 'tecniche', 'di', 'pre-addestramento', 'su', 'dataset', 'di', 'dimensioni', 'enormi', ',', 'che', 'includono', 'miliardi', 'di', 'parole', 'provenienti', 'da', 'libri', ',', 'articoli', 'e', 'pagine', 'web', '.']
# Part of Speech Tagging: [('la', 'DET'), ('loro', 'DET'), ('forza', 'NOUN'), ('risiede', 'VERB'), ('nell’', 'ADP'), ('uso', 'NOUN'), ('di', 'ADP'), ('tecniche', 'NOUN'), ('di', 'ADP'), ('pre', 'ADJ'), ('-', 'PUNCT'), ('addestramento', 'NOUN'), ('su', 'ADP'), ('dataset', 'NOUN'), ('di', 'ADP'), ('dimensioni', 'NOUN'), ('enormi', 'ADJ'), (',', 'PUNCT'), ('che', 'PRON'), ('includono', 'VERB'), ('miliardi', 'NOUN'), ('di', 'ADP'), ('parole', 'NOUN'), ('provenienti', 'VERB'), ('da', 'ADP'), ('libri', 'NOUN'), (',', 'PUNCT'), ('articoli', 'NOUN'), ('e', 'CCONJ'), ('pagine', 'NOUN'), ('web', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['la loro forza', 'uso', 'tecniche', 'pre-addestramento', 'dataset', 'dimensioni enormi', 'che', 'miliardi', 'parole', 'libri', 'articoli', 'pagine']
# Syntactic Parsing: [('la', 'det', 'forza'), ('loro', 'det:poss', 'forza'), ('forza', 'nsubj', 'risiede'), ('risiede', 'ROOT', 'risiede'), ('nell’', 'case', 'uso'), ('uso', 'obl', 'risiede'), ('di', 'case', 'tecniche'), ('tecniche', 'nmod', 'uso'), ('di', 'case', 'addestramento'), ('pre', 'amod', 'addestramento'), ('-', 'punct', 'pre'), ('addestramento', 'nmod', 'tecniche'), ('su', 'case', 'dataset'), ('dataset', 'nmod', 'addestramento'), ('di', 'case', 'dimensioni'), ('dimensioni', 'nmod', 'addestramento'), ('enormi', 'amod', 'dimensioni'), (',', 'punct', 'dimensioni'), ('che', 'nsubj', 'includono'), ('includono', 'acl:relcl', 'tecniche'), ('miliardi', 'obj', 'includono'), ('di', 'case', 'parole'), ('parole', 'nmod', 'miliardi'), ('provenienti', 'acl', 'parole'), ('da', 'case', 'libri'), ('libri', 'obl', 'provenienti'), (',', 'punct', 'libri'), ('articoli', 'nmod', 'libri'), ('e', 'cc', 'pagine'), ('pagine', 'conj', 'articoli'), ('web', 'compound', 'pagine'), ('.', 'punct', 'risiede')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('forza', 'risiede', <generator object at 0x7e41f8247600>)]
# Event Extraction: []
#
# Frase: successivamente, tali modelli possono essere adattati a specifici compiti, come la classificazione, il question answering o la generazione di testo, attraverso un processo noto come fine-tuning.
# Token: ['successivamente', ',', 'tali', 'modelli', 'possono', 'essere', 'adattati', 'a', 'specifici', 'compiti', ',', 'come', 'la', 'classificazione', ',', 'il', 'question', 'answering', 'o', 'la', 'generazione', 'di', 'testo', ',', 'attraverso', 'un', 'processo', 'noto', 'come', 'fine-tuning', '.']
# Part of Speech Tagging: [('successivamente', 'ADV'), (',', 'PUNCT'), ('tali', 'DET'), ('modelli', 'NOUN'), ('possono', 'AUX'), ('essere', 'AUX'), ('adattati', 'VERB'), ('a', 'ADP'), ('specifici', 'ADJ'), ('compiti', 'NOUN'), (',', 'PUNCT'), ('come', 'ADP'), ('la', 'DET'), ('classificazione', 'NOUN'), (',', 'PUNCT'), ('il', 'DET'), ('question', 'NOUN'), ('answering', 'NOUN'), ('o', 'CCONJ'), ('la', 'DET'), ('generazione', 'NOUN'), ('di', 'ADP'), ('testo', 'NOUN'), (',', 'PUNCT'), ('attraverso', 'ADP'), ('un', 'DET'), ('processo', 'NOUN'), ('noto', 'ADJ'), ('come', 'ADP'), ('fine', 'NOUN'), ('-', 'PUNCT'), ('tuning', 'NOUN'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['tali modelli', 'specifici compiti', 'la classificazione', 'il question', 'answering', 'la generazione', 'testo', 'un processo noto come fine', 'tuning']
# ...
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('opportunità', 'straordinarie', <generator object at 0x7e41f82477e0>)]
# Event Extraction: []
#
# Frase: con il miglioramento delle capacità computazionali e lo sviluppo di tecniche sempre più raffinate, si prevede che i futuri modelli saranno in grado di gestire compiti ancora più complessi, come la comprensione del linguaggio multimodale, che integra testo, immagini e audio in un’unica analisi coerente.
# Token: ['con', 'il', 'miglioramento', 'delle', 'capacità', 'computazionali', 'e', 'lo', 'sviluppo', 'di', 'tecniche', 'sempre', 'più', 'raffinate', ',', 'si', 'prevede', 'che', 'i', 'futuri', 'modelli', 'saranno', 'in', 'grado', 'di', 'gestire', 'compiti', 'ancora', 'più', 'complessi', ',', 'come', 'la', 'comprensione', 'del', 'linguaggio', 'multimodale', ',', 'che', 'integra', 'testo', ',', 'immagini', 'e', 'audio', 'in', 'un', '’', 'unica', 'analisi', 'coerente', '.']
# Part of Speech Tagging: [('con', 'ADP'), ('il', 'DET'), ('miglioramento', 'NOUN'), ('delle', 'ADP'), ('capacità', 'NOUN'), ('computazionali', 'ADJ'), ('e', 'CCONJ'), ('lo', 'DET'), ('sviluppo', 'NOUN'), ('di', 'ADP'), ('tecniche', 'NOUN'), ('sempre', 'ADV'), ('più', 'ADV'), ('raffinate', 'ADJ'), (',', 'PUNCT'), ('si', 'PRON'), ('prevede', 'VERB'), ('che', 'SCONJ'), ('i', 'DET'), ('futuri', 'ADJ'), ('modelli', 'NOUN'), ('saranno', 'AUX'), ('in', 'ADP'), ('grado', 'NOUN'), ('di', 'ADP'), ('gestire', 'VERB'), ('compiti', 'NOUN'), ('ancora', 'ADV'), ('più', 'ADV'), ('complessi', 'ADJ'), (',', 'PUNCT'), ('come', 'ADP'), ('la', 'DET'), ('comprensione', 'NOUN'), ('del', 'ADP'), ('linguaggio', 'NOUN'), ('multimodale', 'ADJ'), (',', 'PUNCT'), ('che', 'PRON'), ('integra', 'VERB'), ('testo', 'ADJ'), (',', 'PUNCT'), ('immagini', 'NOUN'), ('e', 'CCONJ'), ('audio', 'NOUN'), ('in', 'ADP'), ('un’', 'DET'), ('unica', 'ADJ'), ('analisi', 'NOUN'), ('coerente', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['il miglioramento', 'capacità computazionali', 'lo sviluppo', 'tecniche sempre più raffinate', 'i futuri modelli', 'compiti ancora più complessi', 'la comprensione', 'linguaggio multimodale', 'che', ', immagini', 'audio', 'un’unica analisi coerente']
# Syntactic Parsing: [('con', 'case', 'miglioramento'), ('il', 'det', 'miglioramento'), ('miglioramento', 'obl', 'prevede'), ('delle', 'case', 'capacità'), ('capacità', 'nmod', 'miglioramento'), ('computazionali', 'amod', 'capacità'), ('e', 'cc', 'sviluppo'), ('lo', 'det', 'sviluppo'), ('sviluppo', 'conj', 'miglioramento'), ('di', 'case', 'tecniche'), ('tecniche', 'nmod', 'sviluppo'), ('sempre', 'advmod', 'più'), ('più', 'advmod', 'raffinate'), ('raffinate', 'amod', 'tecniche'), (',', 'punct', 'miglioramento'), ('si', 'expl:impers', 'prevede'), ('prevede', 'ROOT', 'prevede'), ('che', 'mark', 'grado'), ('i', 'det', 'modelli'), ('futuri', 'amod', 'modelli'), ('modelli', 'nsubj', 'grado'), ('saranno', 'cop', 'grado'), ('in', 'case', 'grado'), ('grado', 'ccomp', 'prevede'), ('di', 'mark', 'gestire'), ('gestire', 'acl', 'grado'), ('compiti', 'obj', 'gestire'), ('ancora', 'advmod', 'più'), ('più', 'advmod', 'complessi'), ('complessi', 'amod', 'compiti'), (',', 'punct', 'gestire'), ('come', 'case', 'comprensione'), ('la', 'det', 'comprensione'), ('comprensione', 'obl', 'gestire'), ('del', 'case', 'linguaggio'), ('linguaggio', 'nmod', 'comprensione'), ('multimodale', 'amod', 'linguaggio'), (',', 'punct', 'comprensione'), ('che', 'nsubj', 'integra'), ('integra', 'acl:relcl', 'comprensione'), ('testo', 'xcomp', 'integra'), (',', 'punct', 'immagini'), ('immagini', 'conj', 'comprensione'), ('e', 'cc', 'audio'), ('audio', 'conj', 'immagini'), ('in', 'case', 'analisi'), ('un’', 'det', 'analisi'), ('unica', 'amod', 'analisi'), ('analisi', 'nmod', 'immagini'), ('coerente', 'amod', 'analisi'), ('.', 'punct', 'prevede')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: []
# Event Extraction: []
#
# Frase: inoltre, l’efficienza computazionale dei modelli rappresenta un’area di ricerca chiave, con l’obiettivo di democratizzare l’accesso a queste tecnologie, rendendole disponibili anche a organizzazioni con risorse limitate.
# Token: ['inoltre', ',', 'l', '’', 'efficienza', 'computazionale', 'dei', 'modelli', 'rappresenta', 'un', '’', 'area', 'di', 'ricerca', 'chiave', ',', 'con', 'l', '’', 'obiettivo', 'di', 'democratizzare', 'l', '’', 'accesso', 'a', 'queste', 'tecnologie', ',', 'rendendole', 'disponibili', 'anche', 'a', 'organizzazioni', 'con', 'risorse', 'limitate', '.']
# Part of Speech Tagging: [('inoltre', 'ADV'), (',', 'PUNCT'), ('l’', 'DET'), ('efficienza', 'NOUN'), ('computazionale', 'ADJ'), ('dei', 'ADP'), ('modelli', 'NOUN'), ('rappresenta', 'VERB'), ('un’', 'DET'), ('area', 'NOUN'), ('di', 'ADP'), ('ricerca', 'NOUN'), ('chiave', 'NOUN'), (',', 'PUNCT'), ('con', 'ADP'), ('l’', 'DET'), ('obiettivo', 'NOUN'), ('di', 'ADP'), ('democratizzare', 'VERB'), ('l’', 'DET'), ('accesso', 'NOUN'), ('a', 'ADP'), ('queste', 'DET'), ('tecnologie', 'NOUN'), (',', 'PUNCT'), ('rendendole', 'VERB'), ('disponibili', 'ADJ'), ('anche', 'ADV'), ('a', 'ADP'), ('organizzazioni', 'NOUN'), ('con', 'ADP'), ('risorse', 'NOUN'), ('limitate', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['l’efficienza computazionale', 'modelli', 'un’area', 'ricerca chiave', 'l’obiettivo', 'l’accesso', 'queste tecnologie', 'anche a organizzazioni', 'risorse limitate']
# Syntactic Parsing: [('inoltre', 'advmod', 'rappresenta'), (',', 'punct', 'inoltre'), ('l’', 'det', 'efficienza'), ('efficienza', 'nsubj', 'rappresenta'), ('computazionale', 'amod', 'efficienza'), ('dei', 'case', 'modelli'), ('modelli', 'nmod', 'efficienza'), ('rappresenta', 'ROOT', 'rappresenta'), ('un’', 'det', 'area'), ('area', 'obj', 'rappresenta'), ('di', 'case', 'ricerca'), ('ricerca', 'nmod', 'area'), ('chiave', 'compound', 'ricerca'), (',', 'punct', 'area'), ('con', 'case', 'obiettivo'), ('l’', 'det', 'obiettivo'), ('obiettivo', 'nmod', 'area'), ('di', 'mark', 'democratizzare'), ('democratizzare', 'acl', 'obiettivo'), ('l’', 'det', 'accesso'), ('accesso', 'obj', 'democratizzare'), ('a', 'case', 'tecnologie'), ('queste', 'det', 'tecnologie'), ('tecnologie', 'nmod', 'accesso'), (',', 'punct', 'democratizzare'), ('rendendole', 'advcl', 'democratizzare'), ('disponibili', 'xcomp', 'rendendole'), ('anche', 'advmod', 'organizzazioni'), ('a', 'case', 'organizzazioni'), ('organizzazioni', 'obl', 'disponibili'), ('con', 'case', 'risorse'), ('risorse', 'nmod', 'organizzazioni'), ('limitate', 'amod', 'risorse'), ('.', 'punct', 'rappresenta')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('efficienza', 'rappresenta', <generator object at 0x7e41f8247880>)]
# Event Extraction: []
#
# Frase: in conclusione, il Natural Language Processing rappresenta una delle aree più dinamiche e in rapida evoluzione dell’Intelligenza Artificiale.
# Token: ['in', 'conclusione', ',', 'il', 'Natural', 'Language', 'Processing', 'rappresenta', 'una', 'delle', 'aree', 'più', 'dinamiche', 'e', 'in', 'rapida', 'evoluzione', 'dell', '’', 'Intelligenza', 'Artificiale', '.']
# Part of Speech Tagging: [('in', 'ADP'), ('conclusione', 'NOUN'), (',', 'PUNCT'), ('il', 'DET'), ('Natural', 'PROPN'), ('Language', 'PROPN'), ('Processing', 'PROPN'), ('rappresenta', 'VERB'), ('una', 'PRON'), ('delle', 'ADP'), ('aree', 'NOUN'), ('più', 'ADV'), ('dinamiche', 'ADJ'), ('e', 'CCONJ'), ('in', 'ADP'), ('rapida', 'ADJ'), ('evoluzione', 'NOUN'), ('dell’', 'ADP'), ('Intelligenza', 'PROPN'), ('Artificiale', 'PROPN'), ('.', 'PUNCT')]
# Named Entity Recognition: [('Natural Language Processing', 'MISC'), ('Intelligenza Artificiale', 'ORG')]
# Key Phrase Extraction: ['conclusione', 'il Natural Language Processing', 'una', 'aree più dinamiche', 'in rapida evoluzione', 'Intelligenza Artificiale']
# Syntactic Parsing: [('in', 'case', 'conclusione'), ('conclusione', 'obl', 'rappresenta'), (',', 'punct', 'conclusione'), ('il', 'det', 'Natural'), ('Natural', 'nsubj', 'rappresenta'), ('Language', 'flat:name', 'Natural'), ('Processing', 'flat:name', 'Natural'), ('rappresenta', 'ROOT', 'rappresenta'), ('una', 'obj', 'rappresenta'), ('delle', 'case', 'aree'), ('aree', 'nmod', 'una'), ('più', 'advmod', 'dinamiche'), ('dinamiche', 'amod', 'aree'), ('e', 'cc', 'evoluzione'), ('in', 'case', 'evoluzione'), ('rapida', 'amod', 'evoluzione'), ('evoluzione', 'conj', 'aree'), ('dell’', 'case', 'Intelligenza'), ('Intelligenza', 'nmod', 'evoluzione'), ('Artificiale', 'flat:name', 'Intelligenza'), ('.', 'punct', 'rappresenta')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('Natural', 'rappresenta', <generator object at 0x7e41f8247740>)]
# Event Extraction: []
#
# Frase: dalla traduzione automatica all’analisi del sentiment, dai chatbot al summarizing, le sue applicazioni hanno un impatto tangibile sulla società, migliorando la produttività e semplificando la vita quotidiana.
# Token: ['dalla', 'traduzione', 'automatica', 'all', '’', 'analisi', 'del', 'sentiment', ',', 'dai', 'chatbot', 'al', 'summarizing', ',', 'le', 'sue', 'applicazioni', 'hanno', 'un', 'impatto', 'tangibile', 'sulla', 'società', ',', 'migliorando', 'la', 'produttività', 'e', 'semplificando', 'la', 'vita', 'quotidiana', '.']
# Part of Speech Tagging: [('dalla', 'ADP'), ('traduzione', 'NOUN'), ('automatica', 'ADJ'), ('all’', 'ADP'), ('analisi', 'NOUN'), ('del', 'ADP'), ('sentiment', 'NOUN'), (',', 'PUNCT'), ('dai', 'ADP'), ('chatbot', 'NOUN'), ('al', 'ADP'), ('summarizing', 'NOUN'), (',', 'PUNCT'), ('le', 'DET'), ('sue', 'DET'), ('applicazioni', 'NOUN'), ('hanno', 'VERB'), ('un', 'DET'), ('impatto', 'NOUN'), ('tangibile', 'ADJ'), ('sulla', 'ADP'), ('società', 'NOUN'), (',', 'PUNCT'), ('migliorando', 'VERB'), ('la', 'DET'), ('produttività', 'NOUN'), ('e', 'CCONJ'), ('semplificando', 'VERB'), ('la', 'DET'), ('vita', 'NOUN'), ('quotidiana', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['traduzione automatica', 'analisi', 'sentiment', ', dai chatbot', 'summarizing', 'le sue applicazioni', 'un impatto tangibile', 'società', 'la produttività', 'la vita quotidiana']
# Syntactic Parsing: [('dalla', 'case', 'traduzione'), ('traduzione', 'obl', 'hanno'), ('automatica', 'amod', 'traduzione'), ('all’', 'case', 'analisi'), ('analisi', 'nmod', 'traduzione'), ('del', 'case', 'sentiment'), ('sentiment', 'nmod', 'analisi'), (',', 'punct', 'chatbot'), ('dai', 'case', 'chatbot'), ('chatbot', 'conj', 'analisi'), ('al', 'case', 'summarizing'), ('summarizing', 'nmod', 'chatbot'), (',', 'punct', 'traduzione'), ('le', 'det', 'applicazioni'), ('sue', 'det:poss', 'applicazioni'), ('applicazioni', 'nsubj', 'hanno'), ('hanno', 'ROOT', 'hanno'), ('un', 'det', 'impatto'), ('impatto', 'obj', 'hanno'), ('tangibile', 'amod', 'impatto'), ('sulla', 'case', 'società'), ('società', 'nmod', 'impatto'), (',', 'punct', 'migliorando'), ('migliorando', 'conj', 'hanno'), ('la', 'det', 'produttività'), ('produttività', 'obj', 'migliorando'), ('e', 'cc', 'semplificando'), ('semplificando', 'conj', 'hanno'), ('la', 'det', 'vita'), ('vita', 'obj', 'semplificando'), ('quotidiana', 'amod', 'vita'), ('.', 'punct', 'hanno')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('applicazioni', 'hanno', <generator object at 0x7e41f82477e0>)]
# Event Extraction: []
#
# Frase: tuttavia, è essenziale affrontare le sfide etiche e tecniche per garantire che queste tecnologie siano sviluppate in modo equo, responsabile e inclusivo.
# Token: ['tuttavia', ',', 'è', 'essenziale', 'affrontare', 'le', 'sfide', 'etiche', 'e', 'tecniche', 'per', 'garantire', 'che', 'queste', 'tecnologie', 'siano', 'sviluppate', 'in', 'modo', 'equo', ',', 'responsabile', 'e', 'inclusivo', '.']
# Part of Speech Tagging: [('tuttavia', 'ADV'), (',', 'PUNCT'), ('è', 'AUX'), ('essenziale', 'ADJ'), ('affrontare', 'VERB'), ('le', 'DET'), ('sfide', 'NOUN'), ('etiche', 'ADJ'), ('e', 'CCONJ'), ('tecniche', 'ADJ'), ('per', 'ADP'), ('garantire', 'VERB'), ('che', 'SCONJ'), ('queste', 'DET'), ('tecnologie', 'NOUN'), ('siano', 'AUX'), ('sviluppate', 'VERB'), ('in', 'ADP'), ('modo', 'NOUN'), ('equo', 'ADJ'), (',', 'PUNCT'), ('responsabile', 'ADJ'), ('e', 'CCONJ'), ('inclusivo', 'ADJ'), ('.', 'PUNCT')]
# Named Entity Recognition: []
# Key Phrase Extraction: ['le sfide etiche e tecniche', 'queste tecnologie', 'modo equo']
# Syntactic Parsing: [('tuttavia', 'advmod', 'essenziale'), (',', 'punct', 'tuttavia'), ('è', 'cop', 'essenziale'), ('essenziale', 'ROOT', 'essenziale'), ('affrontare', 'csubj', 'essenziale'), ('le', 'det', 'sfide'), ('sfide', 'obj', 'affrontare'), ('etiche', 'amod', 'sfide'), ('e', 'cc', 'tecniche'), ('tecniche', 'conj', 'etiche'), ('per', 'mark', 'garantire'), ('garantire', 'advcl', 'affrontare'), ('che', 'mark', 'sviluppate'), ('queste', 'det', 'tecnologie'), ('tecnologie', 'nsubj:pass', 'sviluppate'), ('siano', 'aux:pass', 'sviluppate'), ('sviluppate', 'ccomp', 'garantire'), ('in', 'case', 'modo'), ('modo', 'obl', 'sviluppate'), ('equo', 'amod', 'modo'), (',', 'punct', 'responsabile'), ('responsabile', 'conj', 'sviluppate'), ('e', 'cc', 'inclusivo'), ('inclusivo', 'conj', 'responsabile'), ('.', 'punct', 'essenziale')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: []
# Event Extraction: []
#
# Frase: il futuro dell’NLP appare promettente, con il potenziale di trasformare ulteriormente il modo in cui gli esseri umani interagiscono con la tecnologia e tra loro.
# Token: ['il', 'futuro', 'dell', '’', 'NLP', 'appare', 'promettente', ',', 'con', 'il', 'potenziale', 'di', 'trasformare', 'ulteriormente', 'il', 'modo', 'in', 'cui', 'gli', 'esseri', 'umani', 'interagiscono', 'con', 'la', 'tecnologia', 'e', 'tra', 'loro', '.']
# Part of Speech Tagging: [('il', 'DET'), ('futuro', 'NOUN'), ('dell’', 'ADP'), ('NLP', 'PROPN'), ('appare', 'VERB'), ('promettente', 'ADV'), (',', 'PUNCT'), ('con', 'ADP'), ('il', 'DET'), ('potenziale', 'NOUN'), ('di', 'ADP'), ('trasformare', 'VERB'), ('ulteriormente', 'ADV'), ('il', 'DET'), ('modo', 'NOUN'), ('in', 'ADP'), ('cui', 'PRON'), ('gli', 'DET'), ('esseri', 'NOUN'), ('umani', 'ADJ'), ('interagiscono', 'VERB'), ('con', 'ADP'), ('la', 'DET'), ('tecnologia', 'NOUN'), ('e', 'CCONJ'), ('tra', 'ADP'), ('loro', 'PRON'), ('.', 'PUNCT')]
# Named Entity Recognition: [('NLP', 'ORG')]
# Key Phrase Extraction: ['il futuro', 'NLP', 'il potenziale', 'il modo', 'cui', 'gli esseri umani', 'la tecnologia', 'tra loro']
# Syntactic Parsing: [('il', 'det', 'futuro'), ('futuro', 'nsubj', 'appare'), ('dell’', 'case', 'NLP'), ('NLP', 'nmod', 'futuro'), ('appare', 'ROOT', 'appare'), ('promettente', 'xcomp', 'appare'), (',', 'punct', 'appare'), ('con', 'case', 'potenziale'), ('il', 'det', 'potenziale'), ('potenziale', 'obl', 'appare'), ('di', 'mark', 'trasformare'), ('trasformare', 'acl', 'potenziale'), ('ulteriormente', 'advmod', 'trasformare'), ('il', 'det', 'modo'), ('modo', 'obj', 'trasformare'), ('in', 'case', 'cui'), ('cui', 'obl', 'interagiscono'), ('gli', 'det', 'esseri'), ('esseri', 'nsubj', 'interagiscono'), ('umani', 'amod', 'esseri'), ('interagiscono', 'acl:relcl', 'modo'), ('con', 'case', 'tecnologia'), ('la', 'det', 'tecnologia'), ('tecnologia', 'obl', 'interagiscono'), ('e', 'cc', 'loro'), ('tra', 'case', 'loro'), ('loro', 'conj', 'tecnologia'), ('.', 'punct', 'appare')]
# Coreference Resolution: [('entity1', ['pronome1', 'entità correlata'])]
# Relation Extraction: [('futuro', 'appare', <generator object at 0x7e41f8247740>)]
# Event Extraction: []

# %%
from transformers import pipeline

def chunk_text(text: str, max_tokens: int = 1024) -> list:
    """
    Divide il testo in blocchi di lunghezza massima specificata.
    :param text: Testo da segmentare.
    :param max_tokens: Lunghezza massima per ogni blocco (in token).
    :return: Lista di blocchi di testo.
    """
    sentences = text.split('. ')  # Segmenta il testo in frasi
    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) + 1 <= max_tokens:
            current_chunk += sentence + ". "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "

    if current_chunk:  # Aggiungi l'ultimo blocco
        chunks.append(current_chunk.strip())

    return chunks


def summarize_text(text: str, max_length: int = 200, min_length: int = 100) -> str:
    """
    Riassume il testo utilizzando un modello di Hugging Face.
    :param text: Il testo da riassumere.
    :param max_length: Lunghezza massima del riassunto.
    :param min_length: Lunghezza minima del riassunto.
    :return: Riassunto del testo.
    """
    # Carica la pipeline di summarization
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

    # Suddividi il testo in blocchi gestibili
    chunks = chunk_text(text, max_tokens=1024)

    # Genera i riassunti per ogni blocco
    summaries = []
    for chunk in chunks:
        summary = summarizer(
            chunk,
            max_length=max_length,
            min_length=min_length,
            do_sample=False
        )[0]['summary_text']
        summaries.append(summary)

    # Combina i riassunti in un unico testo
    final_summary = " ".join(summaries)

    # Post-processing: assicurati che termini con un punto
    if not final_summary.endswith('.'):
        last_period_index = final_summary.rfind('.')
        if last_period_index != -1:
            final_summary = final_summary[:last_period_index + 1]

    return final_summary

# Riassunto del testo preprocessato
summary = summarize_text(processed_text, max_length=200, min_length=100)
print("Riassunto del testo:")
print(summary)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device set to use cpu
# Riassunto del testo:
# L'Intelligenza Artificiale (IA) ha avuto un impatto profondo e rivoluzionario su molteplici settori. Il Natural Language Processing (NLP) emerge come uno dei più affascinanti e promettenti. Questo campo combina competenze avanzate di linguistica, informatica e matematica. L’NLP è alla base di molte tecnologie che ormai consideriamo indispensabili nella vita quotidiana. Analisi del sentiment consente individuare tendenze emergenti, anticipare crisi reputazionali e personalizzare le strategie di comunicazione. L’analisi automatizzata di testi provenienti da social media, recensioni e sondaggi, possono ottenere una panoramica delle opinioni e dei sentimenti del pubblico nei confronti di un prodotto, un servizio o un marchio. NLP è il summarizing automatico. Questo strumento permette di sintetizzare grandi quantità di informazioni in riassunti concisi e facilmente comprensibili. la sintesi dei testi è particolarmente utile in settori such as giornalismo. Siri, Alexa e Google Assistant hanno reso possibile un’interazione più naturale tra le persone e i dispositivi tecnologici. Linguaggio naturale ha una capacità senza precedenti di comprendere il contesto. BERT (Bidirectional Encoder Representations from Transformers), GPT (Generative Pre-trained Transformer) e RoBERTa. questi modelli, basati sull’architettura Transformer, hanno rivoluzionato l’approccio tradizionale al linguaggio. successivamente, tali modelli possono essere adattati a specifici compiti, come la classificazione, il question answering o la generazione di testo. GPT-4 è in grado di generare testi indistinguibili da quelli scritti da esseri umani. Queste capacità sollevano interrogativi etici, in particolare riguardo alla possibilità of generare disinformazione su larga scala o contenuti manipolativo. nonostante i notevoli progressi, il campo dell’NLP deve affrontare diverse sfide. una delle più rilevanti riguarda i bias presenti nei dati di addest Sacramento. Linguaggio umano Ù intrinsecamente legato al contesto culturale e temporale. NLP richiede un'attenzione meticolosa nella selezione e nella pulizia dei dati, nonché l'introduzione di metodi per rilevare e mitigare i bias. Fattori come l’ambiguità, l'ironia, il sarcasmo e il linguaggio figurato sono difficili da interpretare anche per i modelli più avanzati. L’efficienza computazionale dei modelli rappresenta un’area di ricerca chiave. Le sue applicazioni hanno un impatto tangibile sulla società. è essenziale affrontare le sfide etiche e tecniche per garantire che queste tecnologie siano sviluppate in modo equo, responsabile e inclusivo.

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Caricamento del modello
model = SentenceTransformer('all-MiniLM-L6-v2')

# Preprocessing del testo originale
processed_text = preprocess_text(processed_text)  # Applica la funzione di preprocessing

# Calcolo degli embeddings per il testo originale e il riassunto
original_embedding = model.encode(processed_text)  # Passa il testo preprocessato
summary_embedding = model.encode(summary)  # Passa il riassunto

# Calcolo della similarità del coseno
similarity = cosine_similarity([original_embedding], [summary_embedding])

# Stampa della similarità
print("Cosine Similarity:", similarity[0][0])
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [nltk_data] Downloading package punkt_tab to ./nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Cosine Similarity: 0.7794912
